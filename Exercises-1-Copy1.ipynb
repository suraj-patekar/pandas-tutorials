# %%
# %matplotlib inline
import pandas as pd

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %%
titles = pd.read_csv('data/titles.csv')
titles.head()
# Out:
#                  title  year
# 0  Zenka - dosu arashi  1969
# 1        Not My Sister  1916
# 2              Salvage  2017
# 3            Ikaw kasi  1955
# 4             Mistress  2018

# %%
cast = pd.read_csv('data/cast.csv')
cast.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %% [markdown]
# ### How many movies are listed in the titles dataframe?

# %%
len(titles)
# Out:
# 226013

# %%
titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 226013 entries, 0 to 226012
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   title   226013 non-null  object
#  1   year    226013 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 3.4+ MB

# %% [markdown]
# ### What are the earliest two films listed in the titles dataframe?

# %%
titles.sort_values('year').head(3)
# Out:
#                                                  title  year
# 90096                                       Miss Jerry  1894
# 74790                               The Startled Lover  1898
# 214140  Reproduction of the Corbett and Jeffries Fight  1899

# %% [markdown]
# ### How many movies have the title "Hamlet"?

# %%
len(titles[titles['title']=='Hamlet'])
# Out:
# 20

# %%
titles[titles['title']=='Hamlet'].sort_values('year')
# Out:
#          title  year
# 85927   Hamlet  1910
# 163782  Hamlet  1911
# 192641  Hamlet  1913
# 192854  Hamlet  1921
# 60006   Hamlet  1948
# 10114   Hamlet  1954
# 215527  Hamlet  1964
# 49125   Hamlet  1969
# 192158  Hamlet  1973
# 113233  Hamlet  1976
# 49911   Hamlet  1987
# 158242  Hamlet  1990
# 202559  Hamlet  1996
# 119813  Hamlet  2000
# 25685   Hamlet  2009
# 55865   Hamlet  2011
# 196714  Hamlet  2014
# 146878  Hamlet  2015
# 38715   Hamlet  2016
# 84066   Hamlet  2017

# %% [markdown]
# ### How many movies are titled "North by Northwest"?

# %%
titles[titles['title']== 'North by Northwest']
# Out:
#                     title  year
# 58655  North by Northwest  1959

# %% [markdown]
# ### When was the first movie titled "Hamlet" made?

# %%
#year 1910

# %% [markdown]
# ### List all of the "Treasure Island" movies from earliest to most recent.

# %%
titles[titles['title']== 'Treasure Island'].sort_values('year')
# Out:
#                   title  year
# 114492  Treasure Island  1918
# 114010  Treasure Island  1920
# 81049   Treasure Island  1934
# 143464  Treasure Island  1950
# 25840   Treasure Island  1972
# 1011    Treasure Island  1973
# 87478   Treasure Island  1985
# 67291   Treasure Island  1999

# %% [markdown]
# ### How many movies were made in the year 1950?

# %%
len(titles[titles['year'] == 1950])
# Out:
# 1109

# %% [markdown]
# ### How many movies were made in the year 1960?

# %%
len(titles[titles['year'] == 1960])
# Out:
# 1496

# %% [markdown]
# ### How many movies were made from 1950 through 1959?

# %%
t = titles[(titles['year'] >= 1950 ) & (titles['year'] <= 1959 )]

# %%
len(t)
# Out:
# 12664

# %% [markdown]
# ### In what years has a movie titled "Batman" been released?

# %%
titles[titles['title'] == 'Batman']
# Out:
#          title  year
# 93241   Batman  1989
# 180773  Batman  1943

# %% [markdown]
# ### How many roles were there in the movie "Inception"?

# %%
cast.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %%
len(cast[cast['title'] == 'Inception'])
# Out:
# 78

# %% [markdown]
# ### How many roles in the movie "Inception" are NOT ranked by an "n" value?

# %%
cast['n'][cast['title'] == 'Inception'].isnull().sum()
# Out:
# 27

# %% [markdown]
# ### But how many roles in the movie "Inception" did receive an "n" value?

# %%
78-27
# Out:
# 51

# %% [markdown]
# ### Display the cast of "North by Northwest" in their correct "n"-value order, ignoring roles that did not earn a numeric "n" value.

# %%
cast[(cast['title'] == 'North by Northwest') & (cast['n'].notnull())].sort_values('n')
# Out:
#                       title  year                  name     type  \
# 797150   North by Northwest  1959            Cary Grant    actor
# 3201980  North by Northwest  1959       Eva Marie Saint  actress
# 1333732  North by Northwest  1959           James Mason    actor
# 2878461  North by Northwest  1959   Jessie Royce Landis  actress
# 326415   North by Northwest  1959        Leo G. Carroll    actor
# 2780220  North by Northwest  1959  Josephine Hutchinson  actress
# 1551491  North by Northwest  1959           Philip Ober    actor
# 1167105  North by Northwest  1959         Martin Landau    actor
# 2239203  North by Northwest  1959         Adam Williams    actor
# 1657968  North by Northwest  1959          Edward Platt    actor
# 609229   North by Northwest  1959     Robert Ellenstein    actor
# 2100440  North by Northwest  1959          Les Tremayne    actor
# 425645   North by Northwest  1959       Philip Coolidge    actor
# ...

# %% [markdown]
# ### Display the entire cast, in "n"-order, of the 1972 film "Sleuth".

# %%
cast[(cast['title'] == 'Sleuth') & (cast['year'] == 1972)].sort_values('n')
# Out:
#           title  year                name     type  \
# 1560814  Sleuth  1972    Laurence Olivier    actor
# 299291   Sleuth  1972       Michael Caine    actor
# 342151   Sleuth  1972      Alec Cawthorne    actor
# 1341313  Sleuth  1972  John (II) Matthews    actor
# 2490141  Sleuth  1972  Eve (III) Channing  actress
# 1325945  Sleuth  1972        Teddy Martin    actor
#
#                           character    n
# 1560814                 Andrew Wyke  1.0
# 299291                  Milo Tindle  2.0
# 342151            Inspector Doppler  3.0
# 1341313  Detective Sergeant Tarrant  4.0
# 2490141             Marguerite Wyke  5.0
# 1325945      Police Constable Higgs  6.0

# %% [markdown]
# ### Now display the entire cast, in "n"-order, of the 2007 version of "Sleuth".

# %%
cast[(cast['title'] == 'Sleuth') & (cast['year'] == 2007)].sort_values('n')
# Out:
#           title  year                 name     type          character    n
# 299292   Sleuth  2007        Michael Caine    actor             Andrew  1.0
# 1183659  Sleuth  2007             Jude Law    actor               Milo  2.0
# 1652936  Sleuth  2007        Harold Pinter    actor        Man on T.V.  3.0
# 238747   Sleuth  2007      Kenneth Branagh    actor  Other Man on T.V.  NaN
# 342152   Sleuth  2007  Alec (II) Cawthorne    actor  Inspector Doppler  NaN
# 2490140  Sleuth  2007    Eve (II) Channing  actress    Marguerite Wyke  NaN
# 3069393  Sleuth  2007    Carmel O'Sullivan  actress             Maggie  NaN

# %% [markdown]
# ### How many roles were credited in the silent 1921 version of Hamlet?

# %%
cast['n'][(cast['title'] == 'Hamlet') & (cast['year'] == 1921)].count()
# Out:
# 9

# %% [markdown]
# ### How many roles were credited in Branagh’s 1996 Hamlet?

# %%
cast['n'][(cast['title'] == 'Hamlet') & (cast['year'] == 1996)].count()
# Out:
# 46

# %%
cast[(cast['title'] == 'Hamlet') & (cast['year'] == 1996)]
# Out:
#           title  year                    name     type  \
# 1547     Hamlet  1996              Riz Abbasi    actor
# 88092    Hamlet  1996    Richard Attenborough    actor
# 145683   Hamlet  1996     Simon Russell Beale    actor
# 196937   Hamlet  1996         David (V) Blair    actor
# 201517   Hamlet  1996           Brian Blessed    actor
# 230146   Hamlet  1996      Christopher Bowles    actor
# 238732   Hamlet  1996         Kenneth Branagh    actor
# 250230   Hamlet  1996          Richard Briers    actor
# 270007   Hamlet  1996          Michael Bryant    actor
# 292609   Hamlet  1996            Peter Bygott    actor
# 315183   Hamlet  1996       Kenneth W Caravan    actor
# 458407   Hamlet  1996           Billy Crystal    actor
# 474456   Hamlet  1996           Charles Daish    actor
# 527361   Hamlet  1996        Gérard Depardieu    actor
# 548010   Hamlet  1996          Reece Dinsdale    actor
# 553205   Hamlet  1996                Ken Dodd    actor
# ...

# %% [markdown]
# ### How many "Hamlet" roles have been listed in all film credits through history?

# %%
len(cast[cast['character'] == 'Hamlet'])
# Out:
# 93

# %% [markdown]
# ### How many people have played an "Ophelia"?

# %%
len(cast[cast['character'] == 'Ophelia'])
# Out:
# 102

# %%
cast[cast['character'] == 'Ophelia']
# Out:
#                                                      title  year  \
# 227897                          The Merry Maids of Madness  2016
# 375914                                      Jake Gets Paid  2009
# 792558                     Dogg's Hamlet, Cahoot's Macbeth  2005
# 1248574                                                 11  2014
# 1447261                                             Kronos  2016
# ...                                                    ...   ...
# 3372861                           Hamlet, Son of a Kingpin  2015
# 3385725                                           D.C. Cab  1983
# 3395743                                             Hamlet  2015
# 3408495  National Theatre Live: Rosencrantz & Guildenst...  2017
# 3411264                                             Hamlet  1996
#
#                         name     type character     n
# 227897           Amy Bourque    actor   Ophelia  11.0
# 375914        Josie Chisholm    actor   Ophelia   NaN
# ...

# %% [markdown]
# ### How many people have played a role called "The Dude"?

# %%
cast[cast['character'] == 'The Dude'].count()
# Out:
# title        17
# year         17
# name         17
# type         17
# character    17
# n            12
# dtype: int64

# %% [markdown]
# ### How many people have played a role called "The Stranger"?

# %%
cast[cast['character'] == 'The Stranger'].count()
# Out:
# title        170
# year         170
# name         170
# type         170
# character    170
# n            113
# dtype: int64

# %% [markdown]
# ### How many roles has Sidney Poitier played throughout his career?

# %%
cast.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %%
len(cast[cast['name'] == 'Sidney Poitier'])
# Out:
# 43

# %% [markdown]
# ### How many roles has Judi Dench played?

# %%
cast[cast['name'] == 'Judi Dench']
# Out:
#                                                title  year        name  \
# 2570293                        84 Charing Cross Road  1987  Judi Dench
# 2570294                            A Handful of Dust  1988  Judi Dench
# 2570295                    A Midsummer Night's Dream  1968  Judi Dench
# 2570296                           A Room with a View  1985  Judi Dench
# 2570297                            A Study in Terror  1965  Judi Dench
# 2570298       Angelina Ballerina: Angelina Sets Sail  2006  Judi Dench
# 2570299      Branagh Theatre Live: The Winter's Tale  2015  Judi Dench
# 2570300                                Casino Royale  2006  Judi Dench
# 2570301                                     Chocolat  2000  Judi Dench
# 2570302                                    Dead Cert  1974  Judi Dench
# 2570303                              Die Another Day  2002  Judi Dench
# 2570304                                       Doogal  2006  Judi Dench
# ...

# %%
len(cast[cast['name'] == 'Judi Dench'])
# Out:
# 55

# %% [markdown]
# ### List the supporting roles (having n=2) played by Cary Grant in the 1940s, in order by year.

# %%
cast[((cast['year']//10 *10) == 1940) & (cast['name'] == 'Cary Grant') & (cast['n'] == 2.0)]
# Out:
#                    title  year        name   type    character    n
# 797147  My Favorite Wife  1940  Cary Grant  actor   Nick Arden  2.0
# 797157    Penny Serenade  1941  Cary Grant  actor  Roger Adams  2.0

# %% [markdown]
# ### List the leading roles that Cary Grant played in the 1940s in order by year.

# %%
cast[((cast['year']//10 *10) == 1940) & (cast['name'] == 'Cary Grant') & (cast['n'] == 1.0)].sort_values('year')
# Out:
#                                        title  year        name   type  \
# 797172               The Howards of Virginia  1940  Cary Grant  actor
# 797131                       His Girl Friday  1940  Cary Grant  actor
# 797174                The Philadelphia Story  1940  Cary Grant  actor
# 797162                             Suspicion  1941  Cary Grant  actor
# 797176                  The Talk of the Town  1942  Cary Grant  actor
# 797153                 Once Upon a Honeymoon  1942  Cary Grant  actor
# 797122                     Destination Tokyo  1943  Cary Grant  actor
# 797146                             Mr. Lucky  1943  Cary Grant  actor
# 797154                      Once Upon a Time  1944  Cary Grant  actor
# 797114                  Arsenic and Old Lace  1944  Cary Grant  actor
# 797149             None But the Lonely Heart  1944  Cary Grant  actor
# 797148                         Night and Day  1946  Cary Grant  actor
# ...

# %% [markdown]
# ### How many roles were available for actors in the 1950s?

# %%
cast[((cast['year']//10 * 10) == 1950) & (cast['type'] == 'actor')].count()
# Out:
# title        153559
# year         153559
# name         153559
# type         153559
# character    153559
# n             79645
# dtype: int64

# %% [markdown]
# ### How many roles were available for actresses in the 1950s?

# %%
cast[((cast['year']//10 * 10) == 1950) & (cast['type'] == 'actress')].count()
# Out:
# title        56331
# year         56331
# name         56331
# type         56331
# character    56331
# n            34839
# dtype: int64

# %% [markdown]
# ### How many leading roles (n=1) were available from the beginning of film history through 1980?

# %%
len(cast[(cast['year'] <= 1980) & (cast['n'] == 1.0)])
# Out:
# 62763

# %% [markdown]
# ### How many non-leading roles were available through from the beginning of film history through 1980?

# %%
len(cast[(cast['year'] <= 1980) & (cast['n'] != 1.0)])
# Out:
# 1078306

# %%
cast[(cast['year'] <= 1980) & (cast['n'] != 1.0)].head()
# Out:
#                                        title  year                   name  \
# 20                            Natas es Satan  1977  Ramon 'Cartucho' Pena
# 26                              Los tarantos  1963             'El Guisa'
# 28                              Los tarantos  1963              'El Viti'
# 35  Been Down So Long It Looks Like Up to Me  1971         Murray the 'K'
# 36                    I Wanna Hold Your Hand  1978         Murray the 'K'
#
#      type         character     n
# 20  actor  Nigth Club Owner   NaN
# 26  actor           Bailaor  25.0
# 28  actor           Cantaor  20.0
# 35  actor           Himself   NaN
# 36  actor           Himself  48.0

# %% [markdown]
# ### How many roles through 1980 were minor enough that they did not warrant a numeric "n" rank?

# %%
len(cast[(cast['year'] <= 1980) & (cast['n'].isnull())])
# Out:
# 437383

# %%
cast[(cast['year'] <= 1980) & (cast['n'].isnull())].head()
# Out:
#                                         title  year                      name  \
# 20                             Natas es Satan  1977     Ramon 'Cartucho' Pena
# 35   Been Down So Long It Looks Like Up to Me  1971            Murray the 'K'
# 108                         Atemlos vor Liebe  1970              Ballett 2000
# 111                       Thunder in Carolina  1960  2nd Marine Division Band
# 114                            Die Todesarena  1953          Die 3 Motorellos
#
#       type         character   n
# 20   actor  Nigth Club Owner NaN
# 35   actor           Himself NaN
# 108  actor        Themselves NaN
# 111  actor        Themselves NaN
# 114  actor        Themselves NaN
