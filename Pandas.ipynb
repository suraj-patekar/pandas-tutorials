# %%
import pandas as pd

# %%
titles = pd.read_csv('data\\titles.csv')

# %%
titles.head()
# Out:
#                  title  year
# 0  Zenka - dosu arashi  1969
# 1        Not My Sister  1916
# 2              Salvage  2017
# 3            Ikaw kasi  1955
# 4             Mistress  2018

# %%
titles.tail()
# Out:
#                                title  year
# 226008                   Lost Angels  1989
# 226009                    Cosmic Sex  2015
# 226010  Assault with a Deadly Weapon  1983
# 226011                   Mano a Mano  2015
# 226012                       Ishqiya  2010

# %%
len(titles)
# Out:
# 226013

# %%
h = titles.head()

# %%
h
# Out:
#                  title  year
# 0  Zenka - dosu arashi  1969
# 1        Not My Sister  1916
# 2              Salvage  2017
# 3            Ikaw kasi  1955
# 4             Mistress  2018

# %%
h['year']
# Out:
# 0    1969
# 1    1916
# 2    2017
# 3    1955
# 4    2018
# Name: year, dtype: int64

# %%
h['year'] + 1000
# Out:
# 0    2969
# 1    2916
# 2    3017
# 3    2955
# 4    3018
# Name: year, dtype: int64

# %%
h['year'] - 1000
# Out:
# 0     969
# 1     916
# 2    1017
# 3     955
# 4    1018
# Name: year, dtype: int64

# %%
h['year']//10*10
# Out:
# 0    1960
# 1    1910
# 2    2010
# 3    1950
# 4    2010
# Name: year, dtype: int64

# %%
h['year']>1985
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# Name: year, dtype: bool

# %%
h[h['year']>1985]
# Out:
#       title  year
# 2   Salvage  2017
# 4  Mistress  2018

# %%
h
# Out:
#                  title  year
# 0  Zenka - dosu arashi  1969
# 1        Not My Sister  1916
# 2              Salvage  2017
# 3            Ikaw kasi  1955
# 4             Mistress  2018

# %%
h[(h['year']<1950) | (h['year']>2000)]
# Out:
#            title  year
# 1  Not My Sister  1916
# 2        Salvage  2017
# 4       Mistress  2018

# %%
titles[titles['title']=='Macbeth'].sort_values('year')
# Out:
#           title  year
# 37290   Macbeth  1913
# 141573  Macbeth  1916
# 47105   Macbeth  1948
# 155160  Macbeth  1987
# 62288   Macbeth  1997
# 22236   Macbeth  1998
# 169997  Macbeth  2003
# 120224  Macbeth  2004
# 120656  Macbeth  2006
# 139375  Macbeth  2009
# 25642   Macbeth  2012
# 25078   Macbeth  2013
# 52541   Macbeth  2014
# 88636   Macbeth  2015
# 33988   Macbeth  2017
# 188670  Macbeth  2018

# %%
cast = pd.read_csv('data/cast.csv')

# %%
cast.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %%
cast.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3442902 entries, 0 to 3442901
# Data columns (total 6 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   title      object
#  1   year       int64
#  2   name       object
#  3   type       object
#  4   character  object
#  5   n          float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 157.6+ MB

# %%
c = cast.head()

# %%
c
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %%
c[c['n'].notnull()]
# Out:
#                  title  year      name   type        character     n
# 0       Closet Monster  2015  Buffy #1  actor          Buffy 4  31.0
# 1      Suuri illusioni  1985    Homo $  actor           Guests  22.0
# 2  Battle of the Sexes  2017   $hutter  actor  Bobby Riggs Fan  10.0

# %%
c[c['n'].isnull()]
# Out:
#                   title  year     name   type                character   n
# 3  Secret in Their Eyes  2015  $hutter  actor          2002 Dodger Fan NaN
# 4            Steve Jobs  2015  $hutter  actor  1988 Opera House Patron NaN

# %%
cast['n'].isnull().sum()
# Out:
# 1327783

# %%
len(cast)
# Out:
# 3442902

# %%
cast['n'].isnull().sum()/len(cast) *100
# Out:
# 38.565808727637325

# %%
h
# Out:
#                  title  year
# 0  Zenka - dosu arashi  1969
# 1        Not My Sister  1916
# 2              Salvage  2017
# 3            Ikaw kasi  1955
# 4             Mistress  2018

# %%
h["title"].str.startswith('Z')
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# Name: title, dtype: bool

# %%
h['title'].str.len()
# Out:
# 0    19
# 1    13
# 2     7
# 3     9
# 4     8
# Name: title, dtype: int64

# %%
h['title'].str.upper()
# Out:
# 0    ZENKA - DOSU ARASHI
# 1          NOT MY SISTER
# 2                SALVAGE
# 3              IKAW KASI
# 4               MISTRESS
# Name: title, dtype: object

# %%
# %matplotlib inline

# %%
titles['year'].value_counts().head()
# Out:
# 2017    9888
# 2016    8198
# 2015    7564
# 2014    7159
# 2013    6896
# Name: year, dtype: int64

# %%
titles['year'].value_counts().sort_index().plot()
# Out:
# <AxesSubplot:>

# %%
kermit = cast[cast['character']=='Kermit the Frog']

# %%
kermit
# Out:
#                                   title  year            name   type  \
# 898272                 Follow That Bird  1985      Jim Henson  actor
# 898277           The Great Muppet Caper  1981      Jim Henson  actor
# 898285                 The Muppet Movie  1979      Jim Henson  actor
# 898292       The Muppets Take Manhattan  1984      Jim Henson  actor
# 2230974  Mr. Magorium's Wonder Emporium  2007  Steve Whitmire  actor
# 2230975          Muppet Treasure Island  1996  Steve Whitmire  actor
# 2230978              Muppets from Space  1999  Steve Whitmire  actor
# 2230984             Muppets Most Wanted  2014  Steve Whitmire  actor
#
#                character     n
# 898272   Kermit the Frog   2.0
# 898277   Kermit the Frog   1.0
# 898285   Kermit the Frog   1.0
# 898292   Kermit the Frog   1.0
# 2230974  Kermit the Frog   8.0
# 2230975  Kermit the Frog  10.0
# 2230978  Kermit the Frog   2.0
# 2230984  Kermit the Frog   4.0

# %%
kermit.plot(x='year',y='n',kind='scatter')
# Out:
# <AxesSubplot:xlabel='year', ylabel='n'>

# %%
kermit[['year','n']]
# Out:
#          year     n
# 898272   1985   2.0
# 898277   1981   1.0
# 898285   1979   1.0
# 898292   1984   1.0
# 2230974  2007   8.0
# 2230975  1996  10.0
# 2230978  1999   2.0
# 2230984  2014   4.0

# %%
# %%time
cast[cast['title']=='Sleuth']
# Out:
# CPU times: total: 438 ms
# Wall time: 432 ms
#           title  year                 name     type  \
# 238747   Sleuth  2007      Kenneth Branagh    actor
# 299291   Sleuth  1972        Michael Caine    actor
# 299292   Sleuth  2007        Michael Caine    actor
# 342151   Sleuth  1972       Alec Cawthorne    actor
# 342152   Sleuth  2007  Alec (II) Cawthorne    actor
# 1183659  Sleuth  2007             Jude Law    actor
# 1325945  Sleuth  1972         Teddy Martin    actor
# 1341313  Sleuth  1972   John (II) Matthews    actor
# 1560814  Sleuth  1972     Laurence Olivier    actor
# 1652936  Sleuth  2007        Harold Pinter    actor
# 2490140  Sleuth  2007    Eve (II) Channing  actress
# 2490141  Sleuth  1972   Eve (III) Channing  actress
# 3069393  Sleuth  2007    Carmel O'Sullivan  actress
#
#                           character    n
# 238747            Other Man on T.V.  NaN
# 299291                  Milo Tindle  2.0
# 299292                       Andrew  1.0
# ...

# %%
c = cast.set_index('title')

# %%
c.head()
# Out:
#                       year      name   type                character     n
# title
# Closet Monster        2015  Buffy #1  actor                  Buffy 4  31.0
# Suuri illusioni       1985    Homo $  actor                   Guests  22.0
# Battle of the Sexes   2017   $hutter  actor          Bobby Riggs Fan  10.0
# Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# Steve Jobs            2015   $hutter  actor  1988 Opera House Patron   NaN

# %%
# %%time
c.loc['Sleuth']
# Out:
# CPU times: total: 203 ms
# Wall time: 206 ms
#         year                 name     type                   character    n
# title
# Sleuth  2007      Kenneth Branagh    actor           Other Man on T.V.  NaN
# Sleuth  1972        Michael Caine    actor                 Milo Tindle  2.0
# Sleuth  2007        Michael Caine    actor                      Andrew  1.0
# Sleuth  1972       Alec Cawthorne    actor           Inspector Doppler  3.0
# Sleuth  2007  Alec (II) Cawthorne    actor           Inspector Doppler  NaN
# Sleuth  2007             Jude Law    actor                        Milo  2.0
# Sleuth  1972         Teddy Martin    actor      Police Constable Higgs  6.0
# Sleuth  1972   John (II) Matthews    actor  Detective Sergeant Tarrant  4.0
# Sleuth  1972     Laurence Olivier    actor                 Andrew Wyke  1.0
# Sleuth  2007        Harold Pinter    actor                 Man on T.V.  3.0
# Sleuth  2007    Eve (II) Channing  actress             Marguerite Wyke  NaN
# ...

# %%
c = c.sort_index()

# %%
c.head()
# Out:
#        year             name     type       character    n
# title
# #211   2018    Liza Mircheva  actress  Elizabeth Grey  NaN
# #211   2018   Rachel O'Meara  actress  Vice Principal  NaN
# #211   2018     Amanda Cerny  actress           Sarah  9.0
# #211   2018   Sophie Skelton  actress    Lisa MacAvoy  2.0
# #211   2018  Mackenzie Evans  actress            Girl  NaN

# %%
# %%time
c.loc['Sleuth']
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
#         year                 name     type                   character    n
# title
# Sleuth  2007    Eve (II) Channing  actress             Marguerite Wyke  NaN
# Sleuth  2007        Michael Caine    actor                      Andrew  1.0
# Sleuth  1972   Eve (III) Channing  actress             Marguerite Wyke  5.0
# Sleuth  2007    Carmel O'Sullivan  actress                      Maggie  NaN
# Sleuth  1972       Alec Cawthorne    actor           Inspector Doppler  3.0
# Sleuth  1972     Laurence Olivier    actor                 Andrew Wyke  1.0
# Sleuth  2007        Harold Pinter    actor                 Man on T.V.  3.0
# Sleuth  2007      Kenneth Branagh    actor           Other Man on T.V.  NaN
# Sleuth  2007             Jude Law    actor                        Milo  2.0
# Sleuth  1972        Michael Caine    actor                 Milo Tindle  2.0
# Sleuth  1972         Teddy Martin    actor      Police Constable Higgs  6.0
# ...

# %%
# %%time
c.loc['Star Wars']
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
#            year               name     type           character     n
# title
# Star Wars  1977       Salo Gardner    actor      Cantina Patron   NaN
# Star Wars  1977        Harold Weed    actor               Melas   NaN
# Star Wars  1977      Harry Fielder    actor  Death Star Trooper   NaN
# Star Wars  1977        Roy Straite    actor      Cantina Patron   NaN
# Star Wars  1977       Doug Beswick    actor       Cantina Alien   NaN
# ...         ...                ...      ...                 ...   ...
# Star Wars  1977      Melissa Kurtz  actress                Jawa   NaN
# Star Wars  1977  Tiffany Hillkurtz  actress                Jawa   NaN
# Star Wars  1977     Alex McCrindle    actor     General Dodonna  14.0
# Star Wars  1977            Mahjoub    actor                Jawa   NaN
# Star Wars  1977         John Sylla    actor      Cantina Voices   NaN
#
# [113 rows x 5 columns]

# %%
# %%time
c.loc['The Wizard of Oz']
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
#                   year                   name     type              character  \
# title
# The Wizard of Oz  1939   Priscilla Montgomery  actress         Munchkin Child
# The Wizard of Oz  1939          Victor Wetter    actor  Munchkin Army Captain
# The Wizard of Oz  1939  'Little Billy' Rhodes    actor     Munchkin Barrister
# The Wizard of Oz  1939           Billie Burke  actress                 Glinda
# The Wizard of Oz  1939  William H. O'Docharty    actor   Munchkin on Carriage
# ...                ...                    ...      ...                    ...
# The Wizard of Oz  1925            Larry Semon    actor              Scarecrow
# The Wizard of Oz  1925      Frederick Ko Vert    actor  Phantom of the Basket
# The Wizard of Oz  1939              Ken Darby    actor     Munchkinland Mayor
# The Wizard of Oz  1939            Valerie Lee  actress               Munchkin
# ...

# %%
a = cast.set_index(['title','year']).sort_index()

# %%
a.head()
# Out:
#                        name     type       character    n
# title year
# #211  2018     Sapir Azulay  actress          Jacobs  NaN
#       2018           Bleona  actress       Christine  NaN
#       2018     Amanda Cerny  actress           Sarah  9.0
#       2018  Mackenzie Evans  actress            Girl  NaN
#       2018    Liza Mircheva  actress  Elizabeth Grey  NaN

# %%
# %%time
a.loc['Sleuth']
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
#                      name     type                   character    n
# year
# 1972        Michael Caine    actor                 Milo Tindle  2.0
# 1972       Alec Cawthorne    actor           Inspector Doppler  3.0
# 1972         Teddy Martin    actor      Police Constable Higgs  6.0
# 1972   John (II) Matthews    actor  Detective Sergeant Tarrant  4.0
# 1972     Laurence Olivier    actor                 Andrew Wyke  1.0
# 1972   Eve (III) Channing  actress             Marguerite Wyke  5.0
# 2007      Kenneth Branagh    actor           Other Man on T.V.  NaN
# 2007        Michael Caine    actor                      Andrew  1.0
# 2007  Alec (II) Cawthorne    actor           Inspector Doppler  NaN
# 2007             Jude Law    actor                        Milo  2.0
# 2007        Harold Pinter    actor                 Man on T.V.  3.0
# 2007    Eve (II) Channing  actress             Marguerite Wyke  NaN
# ...

# %%
a.loc['Sleuth'].loc[1972]
# Out:
#                     name     type                   character    n
# year
# 1972       Michael Caine    actor                 Milo Tindle  2.0
# 1972      Alec Cawthorne    actor           Inspector Doppler  3.0
# 1972        Teddy Martin    actor      Police Constable Higgs  6.0
# 1972  John (II) Matthews    actor  Detective Sergeant Tarrant  4.0
# 1972    Laurence Olivier    actor                 Andrew Wyke  1.0
# 1972  Eve (III) Channing  actress             Marguerite Wyke  5.0

# %%
# %%time
a.loc[('Sleuth',1972)]
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
#                            name     type                   character    n
# title  year
# Sleuth 1972       Michael Caine    actor                 Milo Tindle  2.0
#        1972      Alec Cawthorne    actor           Inspector Doppler  3.0
#        1972        Teddy Martin    actor      Police Constable Higgs  6.0
#        1972  John (II) Matthews    actor  Detective Sergeant Tarrant  4.0
#        1972    Laurence Olivier    actor                 Andrew Wyke  1.0
#        1972  Eve (III) Channing  actress             Marguerite Wyke  5.0

# %%
a.loc[('Sleuth',1972)].reset_index('year')
# Out:
#         year                name     type                   character    n
# title
# Sleuth  1972       Michael Caine    actor                 Milo Tindle  2.0
# Sleuth  1972      Alec Cawthorne    actor           Inspector Doppler  3.0
# Sleuth  1972        Teddy Martin    actor      Police Constable Higgs  6.0
# Sleuth  1972  John (II) Matthews    actor  Detective Sergeant Tarrant  4.0
# Sleuth  1972    Laurence Olivier    actor                 Andrew Wyke  1.0
# Sleuth  1972  Eve (III) Channing  actress             Marguerite Wyke  5.0

# %%
a.loc[('Sleuth',1972)].reset_index(['year','title'])
# Out:
#     title  year                name     type                   character    n
# 0  Sleuth  1972       Michael Caine    actor                 Milo Tindle  2.0
# 1  Sleuth  1972      Alec Cawthorne    actor           Inspector Doppler  3.0
# 2  Sleuth  1972        Teddy Martin    actor      Police Constable Higgs  6.0
# 3  Sleuth  1972  John (II) Matthews    actor  Detective Sergeant Tarrant  4.0
# 4  Sleuth  1972    Laurence Olivier    actor                 Andrew Wyke  1.0
# 5  Sleuth  1972  Eve (III) Channing  actress             Marguerite Wyke  5.0

# %%
c = cast
c = c[c['name']=='George Clooney']

# %%
c.groupby(['title','year','character']).size()
# Out:
# title                               year  character
# Batman & Robin                      1997  Batman                      1
#                                           Bruce Wayne                 1
# Burn After Reading                  2008  Harry Pfarrer               1
# Confessions of a Dangerous Mind     2002  Jim Byrd                    1
# Curdled                             1996  Seth Gecko                  1
# Fantastic Mr. Fox                   2009  Mr. Fox                     1
# Good Night, and Good Luck.          2005  Fred Friendly               1
# Gravity                             2013  Matt Kowalski               1
# Hail, Caesar!                       2016  Baird Whitlock              1
# Intolerable Cruelty                 2003  Miles                       1
# Leatherheads                        2008  Dodge Connelly              1
# Michael Clayton                     2007  Michael Clayton             1
# ...

# %%
c.groupby('year').size().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='year'>

# %%
c.groupby('year').size().plot(ylim=0)
# Out:
# <AxesSubplot:xlabel='year'>

# %%
c.groupby('year')['n'].max()
# Out:
# year
# 1992    23.0
# 1996     2.0
# 1997     2.0
# 1998    14.0
# 1999    11.0
# 2000     1.0
# 2001    36.0
# 2002    17.0
# 2003    22.0
# 2004     3.0
# 2005    15.0
# 2006     1.0
# 2007     6.0
# 2008     5.0
# 2009     1.0
# 2010     1.0
# 2011     2.0
# 2013     2.0
# 2014     1.0
# 2015     1.0
# 2016     2.0
# Name: n, dtype: float64

# %%
c.groupby('year')['n'].min()
# Out:
# year
# 1992    5.0
# 1996    2.0
# 1997    1.0
# 1998    1.0
# 1999    1.0
# 2000    1.0
# 2001    1.0
# 2002    1.0
# 2003    1.0
# 2004    3.0
# 2005    2.0
# 2006    1.0
# 2007    1.0
# 2008    1.0
# 2009    1.0
# 2010    1.0
# 2011    1.0
# 2013    2.0
# 2014    1.0
# 2015    1.0
# 2016    1.0
# Name: n, dtype: float64

# %%
c.groupby(c['year']//10 *10)['n'].size()
# Out:
# year
# 1990    13
# 2000    20
# 2010    10
# Name: n, dtype: int64

# %%
cast.groupby('type')['title'].count()
# Out:
# type
# actor      2317612
# actress    1125290
# Name: title, dtype: int64

# %%
cast.groupby([cast['year']//10 *10,'type']).size()
# Out:
# year  type
# 1890  actor           2
#       actress         1
# 1900  actor          54
#       actress        16
# 1910  actor       27396
#       actress     15733
# 1920  actor       48112
#       actress     23826
# 1930  actor      149272
#       actress     49298
# 1940  actor      159799
#       actress     50871
# 1950  actor      153559
#       actress     56331
# 1960  actor      128132
#       actress     54484
# 1970  actor      142015
#       actress     60977
# 1980  actor      177064
#       actress     80619
# 1990  actor      245713
#       actress    115505
# 2000  actor      440810
#       actress    235217
# 2010  actor      645548
#       actress    382288
# 2020  actor         134
#       actress       123
# 2110  actor           2
#       actress         1
# dtype: int64

# %%
c = cast
c = c[(c['character']=='Kermit the Frog') | (c['character']=='Oscar the Grouch')]

# %%
c
# Out:
#                                                   title  year            name  \
# 898272                                 Follow That Bird  1985      Jim Henson
# 898277                           The Great Muppet Caper  1981      Jim Henson
# 898285                                 The Muppet Movie  1979      Jim Henson
# 898292                       The Muppets Take Manhattan  1984      Jim Henson
# 1973419                                Follow That Bird  1985  Caroll Spinney
# 1973422  Night at the Museum: Battle of the Smithsonian  2009  Caroll Spinney
# 1973426            The Adventures of Elmo in Grouchland  1999  Caroll Spinney
# 1973427                          The Great Muppet Caper  1981  Caroll Spinney
# 2230974                  Mr. Magorium's Wonder Emporium  2007  Steve Whitmire
# 2230975                          Muppet Treasure Island  1996  Steve Whitmire
# 2230978                              Muppets from Space  1999  Steve Whitmire
# ...

# %%
g = c.groupby(['character',c['year']//10 *10]).size()

# %%
u = g.unstack(0)

# %%
u
# Out:
# character  Kermit the Frog  Oscar the Grouch
# year
# 1970                   1.0               NaN
# 1980                   3.0               2.0
# 1990                   2.0               1.0
# 2000                   1.0               1.0
# 2010                   1.0               NaN

# %%
u['Kermit the Frog'] - u['Oscar the Grouch']
# Out:
# year
# 1970    NaN
# 1980    1.0
# 1990    1.0
# 2000    0.0
# 2010    NaN
# dtype: float64

# %%
u = u.fillna(0)

# %%
u
# Out:
# character  Kermit the Frog  Oscar the Grouch
# year
# 1970                   1.0               0.0
# 1980                   3.0               2.0
# 1990                   2.0               1.0
# 2000                   1.0               1.0
# 2010                   1.0               0.0

# %%
u['Kermit the Frog'] - u['Oscar the Grouch']
# Out:
# year
# 1970    1.0
# 1980    1.0
# 1990    1.0
# 2000    0.0
# 2010    1.0
# dtype: float64

# %%
g
# Out:
# character         year
# Kermit the Frog   1970    1
#                   1980    3
#                   1990    2
#                   2000    1
#                   2010    1
# Oscar the Grouch  1980    2
#                   1990    1
#                   2000    1
# dtype: int64

# %%
g.unstack('character')
# Out:
# character  Kermit the Frog  Oscar the Grouch
# year
# 1970                   1.0               NaN
# 1980                   3.0               2.0
# 1990                   2.0               1.0
# 2000                   1.0               1.0
# 2010                   1.0               NaN

# %%
g.unstack('character').unstack('year')
# Out:
# character         year
# Kermit the Frog   1970    1.0
#                   1980    3.0
#                   1990    2.0
#                   2000    1.0
#                   2010    1.0
# Oscar the Grouch  1970    NaN
#                   1980    2.0
#                   1990    1.0
#                   2000    1.0
#                   2010    NaN
# dtype: float64

# %%
g.unstack()
# Out:
# year              1970  1980  1990  2000  2010
# character
# Kermit the Frog    1.0   3.0   2.0   1.0   1.0
# Oscar the Grouch   NaN   2.0   1.0   1.0   NaN

# %%
g = c.groupby(['character',c['year']//10 *10]).size()

# %%
g.unstack()
# Out:
# year              1970  1980  1990  2000  2010
# character
# Kermit the Frog    1.0   3.0   2.0   1.0   1.0
# Oscar the Grouch   NaN   2.0   1.0   1.0   NaN

# %%
df = g.unstack('character')

# %%
df
# Out:
# character  Kermit the Frog  Oscar the Grouch
# year
# 1970                   1.0               NaN
# 1980                   3.0               2.0
# 1990                   2.0               1.0
# 2000                   1.0               1.0
# 2010                   1.0               NaN

# %%
df['extra'] = 1

# %%
df
# Out:
# character  Kermit the Frog  Oscar the Grouch  extra
# year
# 1970                   1.0               NaN      1
# 1980                   3.0               2.0      1
# 1990                   2.0               1.0      1
# 2000                   1.0               1.0      1
# 2010                   1.0               NaN      1

# %%
df = df.set_index('extra',drop = True, append = True)

# %%
df
# Out:
# character   Kermit the Frog  Oscar the Grouch
# year extra
# 1970 1                  1.0               NaN
# 1980 1                  3.0               2.0
# 1990 1                  2.0               1.0
# 2000 1                  1.0               1.0
# 2010 1                  1.0               NaN

# %%
df.unstack(0)
# Out:
# character Kermit the Frog                     Oscar the Grouch                 \
# year                 1970 1980 1990 2000 2010             1970 1980 1990 2000
# extra
# 1                     1.0  3.0  2.0  1.0  1.0              NaN  2.0  1.0  1.0
#
# character
# year      2010
# extra
# 1          NaN

# %%
act = cast.groupby(['year','type']).size()

# %%
act.head(9)
# Out:
# year  type
# 1894  actor       2
#       actress     1
# 1900  actor       2
# 1905  actor       1
# 1906  actor      14
#       actress     3
# 1907  actor       5
# 1908  actor      29
#       actress    13
# dtype: int64

# %%
act = act.unstack()

# %%
act
# Out:
# type  actor  actress
# year
# 1894    2.0      1.0
# 1900    2.0      NaN
# 1905    1.0      NaN
# 1906   14.0      3.0
# 1907    5.0      NaN
# ...     ...      ...
# 2022   12.0      4.0
# 2023    2.0      NaN
# 2024    5.0      3.0
# 2025    5.0      4.0
# 2115    2.0      1.0
#
# [124 rows x 2 columns]

# %%
act.fillna(0,inplace=True)

# %%
act
# Out:
# type  actor  actress
# year
# 1894    2.0      1.0
# 1900    2.0      0.0
# 1905    1.0      0.0
# 1906   14.0      3.0
# 1907    5.0      0.0
# ...     ...      ...
# 2022   12.0      4.0
# 2023    2.0      0.0
# 2024    5.0      3.0
# 2025    5.0      4.0
# 2115    2.0      1.0
#
# [124 rows x 2 columns]

# %%
act['difference'] = act['actor'] - act['actress']

# %%
act.head()
# Out:
# type  actor  actress  difference
# year
# 1894    2.0      1.0         1.0
# 1900    2.0      0.0         2.0
# 1905    1.0      0.0         1.0
# 1906   14.0      3.0        11.0
# 1907    5.0      0.0         5.0

# %%
act['difference'].plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
(act['actor']/(act['actor']+act['actress'])).plot(ylim = (0,1))
# Out:
# <AxesSubplot:xlabel='year'>

# %%
c = cast[cast['n'] == 2]

# %%
act = c.groupby(['year','type']).size()
act = act.unstack()
act.fillna(0,inplace=True)

# %%
act
# Out:
# type   actor  actress
# year
# 1906     2.0      1.0
# 1907     1.0      0.0
# 1908     2.0      0.0
# 1910     2.0      2.0
# 1911    13.0      4.0
# ...      ...      ...
# 2016  1914.0   1561.0
# 2017  1678.0   1501.0
# 2018   294.0    471.0
# 2019    10.0      8.0
# 2020     0.0      1.0
#
# [114 rows x 2 columns]

# %%
(act['actor']/(act['actor']+act['actress'])).plot(ylim = (0,1))
# Out:
# <AxesSubplot:xlabel='year'>

# %%
c = cast
c = c[c['n'] <= 3]

# %%
c = c.groupby(['year','type','n']).size()

# %%
c
# Out:
# year  type     n
# 1906  actor    1.0     2
#                2.0     2
#       actress  1.0     1
#                2.0     1
#                3.0     1
#                       ..
# 2019  actress  1.0    16
#                2.0     8
#                3.0    11
# 2020  actor    1.0     4
#       actress  2.0     1
# Length: 673, dtype: int64

# %%
c = c.unstack('type')

# %%
(c['actor']/(c['actor']+c['actress'])).unstack('n').plot(ylim=(0,1))
# Out:
# <AxesSubplot:xlabel='year'>

# %%
# Out:
# type   actor                 actress
# n        1.0     2.0     3.0     1.0     2.0     3.0
# year
# 1906     2.0     2.0     NaN     1.0     1.0     1.0
# 1907     1.0     1.0     1.0     NaN     NaN     NaN
# 1908     1.0     2.0     2.0     NaN     NaN     NaN
# 1909     1.0     NaN     NaN     NaN     NaN     NaN
# 1910     1.0     2.0     3.0     4.0     2.0     NaN
# ...      ...     ...     ...     ...     ...     ...
# 2016  2530.0  1914.0  1893.0  1170.0  1561.0  1392.0
# 2017  2073.0  1678.0  1655.0  1295.0  1501.0  1253.0
# 2018   359.0   294.0   254.0   440.0   471.0   389.0
# 2019    11.0    10.0     6.0    16.0     8.0    11.0
# 2020     4.0     NaN     NaN     NaN     1.0     NaN
#
# [115 rows x 6 columns]

# %%
(c['actor']/(c['actor']+c['actress'])).plot(ylim=(0,1))
# Out:
# <AxesSubplot:xlabel='year'>
